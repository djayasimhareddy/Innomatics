# %%
#question 1
print("Hello, World!")
# Out:
# Hello, World!

# %%
#question 2
n = int(input())
if(n%2==0):
  if((n>=2 and n<5 )or n>20):
    print("Not Weird")
  elif(n>=6 and n<=20):
    print("Weird")
else :
  print("Weird")
# Out:
# 4
# Not Weird

# %%
#question 3
 a = int(input())
 b = int(input())
 print(a+b)
 print(a-b)
 print(a*b)
# Out:
# 5
# 6
# 11
# -1
# 30

# %%
#question 4
c=int(input())
d=int(input())
print(a//b)
print(a/b)
# Out:
# 4
# 5
# 0
# 0.8333333333333334

# %%
#question 5
n=int(input())
for i in range(n):
  print(i*i)
# Out:
# 4
# 0
# 1
# 4
# 9

# %%
#question 6

def is_leap(year):
    leap = False
    if(year %4==0):
        leap = True
        if(year %100 ==0):
            leap = False
            if(year%400 == 0):
                leap = True

    return leap

year = int(input())
print(is_leap(n))
# Out:
# 1990
# True

# %%
#question 7
n = int(input())
st = ""
for i in range(1,n+1):
    st += str(i)
print(st)
# Out:
# 4
# 1234
